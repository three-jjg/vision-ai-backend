# %%
import os
import keras
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ### Experimenting with CelebFaces
# * We load the imgs with CV2 which loads in BGR on 255 scale
# * We convert to BGR -> RGB on 1 scale

# %%
img = cv2.imread('../dataset/faces/000001.jpg')

# %%
print(img.shape)
# Out:
# (218, 178, 3)

# %%
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
print(rgb_img[0,0,:]/255)
# Out:
# [0.99215686 0.90588235 0.76078431]

# %%
plt.imshow(rgb_img)

# %% [markdown]
# ### Prepare dataset for training
# * Load images from directory
# * Convert BGR scale 255 to RBG with scale of 1

# %%
files = os.listdir('../dataset/faces/')

# %%
imgs = np.array([])
y = np.array([])
for i,x in enumerate(files[0:5]):
    print(i)
    img = cv2.imread('../dataset/faces/%s'% x)
    rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)[0,0,:]/255
#     imgs = np.append(imgs,[rgb_img])
    y = np.array(np.concatenate((imgs, rgb_img), axis=0))
    y = np.append(y,np.array(np.concatenate((imgs, rgb_img), axis=0)))
    print(np.concatenate((imgs, rgb_img), axis=0))
#     imgs[i] = []
#     imgs[i].append(rgb_img)
# Out:
# 0
# [0.30196078 0.34901961 0.16862745]
# 1
# [0. 0. 0.]
# 2
# [0.75294118 0.78039216 0.81960784]
# 3
# [0.76862745 0.79607843 0.90588235]
# 4
# [0. 0. 0.]
